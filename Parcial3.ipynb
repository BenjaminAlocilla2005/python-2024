# %% [markdown]
# 1. Se tiene un dataset de Spotify (songs_normalize), el cual tiene un
# resumen de la información de canciones y artistas. Se solicita limpiar el
# dataset y hacer lo siguiente: (60 Puntos)

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
Spotify = ('/content/drive/My Drive/Pandas/songs_normalize.csv')

# %% [markdown]
# a. Mostrar la información general del Dataset, y la información
# estadística resumida.

# %%
datosSp = pd.read_csv(Spotify)
datosSp
# Out:
#               artist                                    song  duration_ms  \
# 0     Britney Spears                  Oops!...I Did It Again       211160
# 1          blink-182                    All The Small Things       167066
# 2         Faith Hill                                 Breathe       250546
# 3           Bon Jovi                            It's My Life       224493
# 4             *NSYNC                             Bye Bye Bye       200560
# ...              ...                                     ...          ...
# 1995  Jonas Brothers                                  Sucker       181026
# 1996    Taylor Swift                            Cruel Summer       178426
# 1997    Blanco Brown                              The Git Up       200593
# 1998       Sam Smith  Dancing With A Stranger (with Normani)       171029
# 1999     Post Malone                                 Circles       215280
#
#       explicit  year  popularity  danceability  energy  key  loudness  mode  \
# ...

# %%
datosSp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   artist            2000 non-null   object
#  1   song              1999 non-null   object
#  2   duration_ms       2000 non-null   int64
#  3   explicit          2000 non-null   bool
#  4   year              2000 non-null   int64
#  5   popularity        2000 non-null   int64
#  6   danceability      2000 non-null   float64
#  7   energy            2000 non-null   float64
#  8   key               2000 non-null   int64
#  9   loudness          2000 non-null   float64
#  10  mode              2000 non-null   int64
#  11  speechiness       2000 non-null   float64
#  12  acousticness      2000 non-null   float64
#  13  instrumentalness  2000 non-null   float64
#  14  liveness          2000 non-null   float64
#  15  valence           2000 non-null   float64
# ...

# %%
datosSp.head(21)
# Out:
#              artist                                              song  \
# 0    Britney Spears                            Oops!...I Did It Again
# 1         blink-182                              All The Small Things
# 2        Faith Hill                                           Breathe
# 3          Bon Jovi                                      It's My Life
# 4            *NSYNC                                       Bye Bye Bye
# 5             Sisqo                                        Thong Song
# 6            Eminem                               The Real Slim Shady
# 7   Robbie Williams                                           Rock DJ
# 8   Destiny's Child                                       Say My Name
# 9             Modjo                            Lady - Hear Me Tonight
# 10  Gigi D'Agostino                                  L'Amour Toujours
# 11        Eiffel 65  Move Your Body - Gabry Ponte Original Radio Edit
# ...

# %%
Info_de_musica = (f'La informacion de canciones de Spotify: {datosSp.shape}')
Info_de_musica
# Out:
# 'La informacion de canciones de Spotify: (2000, 18)'

# %% [markdown]
# b. Contar todos los valores nulos existentes en el dataset e
# imprimirlos. Luego, eliminar los valores nulos encontrados.

# %%
Info_nulo = pd.isnull(datosSp)
Info_nulo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   artist            2000 non-null   bool
#  1   song              2000 non-null   bool
#  2   duration_ms       2000 non-null   bool
#  3   explicit          2000 non-null   bool
#  4   year              2000 non-null   bool
#  5   popularity        2000 non-null   bool
#  6   danceability      2000 non-null   bool
#  7   energy            2000 non-null   bool
#  8   key               2000 non-null   bool
#  9   loudness          2000 non-null   bool
#  10  mode              2000 non-null   bool
#  11  speechiness       2000 non-null   bool
#  12  acousticness      2000 non-null   bool
#  13  instrumentalness  2000 non-null   bool
#  14  liveness          2000 non-null   bool
#  15  valence           2000 non-null   bool
#  16  tempo             2000 non-null   bool
# ...

# %%
pd.notnull(Info_nulo)
Info_nulo
# Out:
#       artist   song  duration_ms  explicit   year  popularity  danceability  \
# 0      False  False        False     False  False       False         False
# 1      False  False        False     False  False       False         False
# 2      False  False        False     False  False       False         False
# 3      False  False        False     False  False       False         False
# 4      False  False        False     False  False       False         False
# ...      ...    ...          ...       ...    ...         ...           ...
# 1995   False  False        False     False  False       False         False
# 1996   False  False        False     False  False       False         False
# 1997   False  False        False     False  False       False         False
# 1998   False  False        False     False  False       False         False
# 1999   False  False        False     False  False       False         False
#
# ...

# %% [markdown]
# c. Filtrar las canciones con contenido explícito (‘explicit’). Mostrar las primeras 10
# canciones con contenido explícito en formato de tabla.

# %%
explicit_music = datosSp[datosSp['explicit'].info(axis=1)]
explicit_music.head(11)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-81-7ed18e6d98f6> in <cell line: 1>()
# ----> 1 explicit_music = datosSp[datosSp['explicit'].info(axis=1)]
#       2 explicit_music.head(11)
#
# TypeError: Series.info() got an unexpected keyword argument 'axis'

# %% [markdown]
# d. Obtener el promedio de la duración de todas las canciones (‘duration_ms’)

# %%
duration_of_music = datosSp[datosSp['duration_ms'].info(axis=1)]
duration_of_music
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-82-ef2d32bb26c4> in <cell line: 1>()
# ----> 1 duration_of_music = datosSp[datosSp['duration_ms'].info(axis=1)]
#       2 duration_of_music
#
# TypeError: Series.info() got an unexpected keyword argument 'axis'

# %% [markdown]
# 2. Crear un gráfico de barras que muestre la cantidad de canciones explícitas por artista.
# Tomar el dataframe creado en la letra C del ejercicio 1 y la columna (‘artist’) en el dataset.
# (40 Puntos)

# %%
explicit_music.groupby('x')
plt.figure()
plt.plot(explicit_music,color='blue',kind=bar)

plt.show
